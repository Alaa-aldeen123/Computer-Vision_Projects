# %%
pip install openai

# %%
openai_api_key ='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'

# %%
from openai import OpenAI

client=OpenAI(
    api_key=openai_api_key
    )

# %%
prompt='picture of a modern vella which blend with it is surrounding environment'

response=client.images.generate(
    model='dall-e-2',
    prompt=prompt,
    size='1024x1024',
    quality='standard',
    n=1,
)

print(response)
# Out:
# ImagesResponse(created=1737966091, data=[Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-j5LEhWw01p6KXuLTZD8aZTXQ.png?st=2025-01-27T07%3A21%3A31Z&se=2025-01-27T09%3A21%3A31Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-26T20%3A16%3A08Z&ske=2025-01-27T20%3A16%3A08Z&sks=b&skv=2024-08-04&sig=6JDtDIJgBZMAbwawwg0d5mJAz1dwNZC/jBwOM4xYG%2B8%3D')])

# %%
print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-j5LEhWw01p6KXuLTZD8aZTXQ.png?st=2025-01-27T07%3A21%3A31Z&se=2025-01-27T09%3A21%3A31Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-26T20%3A16%3A08Z&ske=2025-01-27T20%3A16%3A08Z&sks=b&skv=2024-08-04&sig=6JDtDIJgBZMAbwawwg0d5mJAz1dwNZC/jBwOM4xYG%2B8%3D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ast import mod
img_path= '/content/drive/MyDrive/AI course/Computer_Vesion/DALL.E/img.png'

response= client.images.create_variation(
    model='dall-e-2',
    image=open(img_path, 'rb'),
    n=3,
    size='1024x1024'
)
print(response)
# Out:
# ImagesResponse(created=1737967381, data=[Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-FMmsP6yIj05Yo1p9AsrE0P8s.png?st=2025-01-27T07%3A43%3A01Z&se=2025-01-27T09%3A43%3A01Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A26%3A10Z&ske=2025-01-28T00%3A26%3A10Z&sks=b&skv=2024-08-04&sig=OUgbQ1UYNuIJr79inAcB6xl0dmxjXbMSL0t%2BzyIkesY%3D'), Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-LJvR8nxn26JpGV6lNvhlgGSl.png?st=2025-01-27T07%3A43%3A00Z&se=2025-01-27T09%3A43%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A26%3A10Z&ske=2025-01-2
# ...

# %%
print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-FMmsP6yIj05Yo1p9AsrE0P8s.png?st=2025-01-27T07%3A43%3A01Z&se=2025-01-27T09%3A43%3A01Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A26%3A10Z&ske=2025-01-28T00%3A26%3A10Z&sks=b&skv=2024-08-04&sig=OUgbQ1UYNuIJr79inAcB6xl0dmxjXbMSL0t%2BzyIkesY%3D

# %%
print(response.data[1].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-LJvR8nxn26JpGV6lNvhlgGSl.png?st=2025-01-27T07%3A43%3A00Z&se=2025-01-27T09%3A43%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A26%3A10Z&ske=2025-01-28T00%3A26%3A10Z&sks=b&skv=2024-08-04&sig=hS0qJjhy%2BXuoZPf8tJTeF/ymlbJd0HofFYIgv6yxyFg%3D

# %%
print(response.data[2].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-eJvJpsXbjWzs4EKTKMRi3h5Q.png?st=2025-01-27T07%3A43%3A00Z&se=2025-01-27T09%3A43%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A26%3A10Z&ske=2025-01-28T00%3A26%3A10Z&sks=b&skv=2024-08-04&sig=YTr2bP/rvAN3s9i0LksCZNPTROEvYT6uvIsHdzAHnUk%3D

# %%
response= client.images.generate(
    model='dall-e-3',
    prompt=prompt,
    size='1024x1024',
    quality='standard',
    n=1,
)
print(response)
# Out:
# ImagesResponse(created=1737967651, data=[Image(b64_json=None, revised_prompt='Visualize an exemplary model of a modern villa that seamlessly blends with its surrounding environment. The villa should be architecturally contemporary, incorporating large glass windows for natural light, and aesthetically pleasing outdoor spaces with lush greenery that co-exists with the dwelling. The overall result should be a harmony between the building and its landscape, achieving a balance that underscores sustainability and respects natural aesthetics.', url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-zP3PbSQWOd1bOJMq6lkP1Gmr.png?st=2025-01-27T07%3A47%3A31Z&se=2025-01-27T09%3A47%3A31Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A24%3A11Z&ske=2025-01-28T00%3A24%3A11Z&sks=b&skv=2024-08-04&sig=CfmbyX9C3ckyHj9dgUoUL
# ...

# %%
print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lfBWDmkv4adYriBwBi7b0Kgm/user-17psUCTAGOp0kjNsQOG7SHKm/img-zP3PbSQWOd1bOJMq6lkP1Gmr.png?st=2025-01-27T07%3A47%3A31Z&se=2025-01-27T09%3A47%3A31Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-27T00%3A24%3A11Z&ske=2025-01-28T00%3A24%3A11Z&sks=b&skv=2024-08-04&sig=CfmbyX9C3ckyHj9dgUoULjBu0AlIWaiT9eWL0SfKBWo%3D
